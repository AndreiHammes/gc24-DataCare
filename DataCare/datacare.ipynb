# %%
import pandas as pd

# %%
df = pd.read_csv("depression_dataset.csv")
df.head()
# Out:
#       Name  Gender  Age       City Working Professional or Student  \
# 0    Pooja  Female   37  Ghaziabad            Working Professional
# 1  Reyansh    Male   60     Kalyan            Working Professional
# 2    Manvi  Female   42     Bhopal            Working Professional
# 3     Isha  Female   44      Thane            Working Professional
# 4    Aarav    Male   48     Indore            Working Professional
#
#           Profession  Academic Pressure  Work Pressure  CGPA  \
# 0            Teacher                NaN            2.0   NaN
# 1  Financial Analyst                NaN            4.0   NaN
# 2            Teacher                NaN            2.0   NaN
# 3            Teacher                NaN            3.0   NaN
# 4     UX/UI Designer                NaN            4.0   NaN
#
#    Study Satisfaction  Job Satisfaction Sleep Duration Dietary Habits Degree  \
# 0                 NaN               4.0      7-8 hours       Moderate     MA
# 1                 NaN               3.0      5-6 hours      Unhealthy  B.Com
# 2                 NaN               3.0      5-6 hours       Moderate  M.Com
# 3                 NaN               5.0      7-8 hours        Healthy     MD
# 4                 NaN               3.0      7-8 hours       Moderate     BE
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# 0                                    No                 6                 2
# 1                                   Yes                 0                 4
# 2                                    No                 0                 2
# 3                                   Yes                 1                 2
# 4                                   Yes                 6                 5
#
#   Family History of Mental Illness Depression
# 0                               No         No
# 1                              Yes         No
# 2                               No         No
# 3                              Yes         No
# 4                              Yes         No

# %%
#Transformando coluna 'Gender' em variáveis numéricas

sex = pd.get_dummies(df['Gender'], dtype=int)
df[['Female', 'Male']] = sex
df.drop(['Gender', 'Female'], axis=1, inplace=True)
df.head()
# Out:
#       Name  Age       City Working Professional or Student         Profession  \
# 0    Pooja   37  Ghaziabad            Working Professional            Teacher
# 1  Reyansh   60     Kalyan            Working Professional  Financial Analyst
# 2    Manvi   42     Bhopal            Working Professional            Teacher
# 3     Isha   44      Thane            Working Professional            Teacher
# 4    Aarav   48     Indore            Working Professional     UX/UI Designer
#
#    Academic Pressure  Work Pressure  CGPA  Study Satisfaction  \
# 0                NaN            2.0   NaN                 NaN
# 1                NaN            4.0   NaN                 NaN
# 2                NaN            2.0   NaN                 NaN
# 3                NaN            3.0   NaN                 NaN
# 4                NaN            4.0   NaN                 NaN
#
#    Job Satisfaction Sleep Duration Dietary Habits Degree  \
# 0               4.0      7-8 hours       Moderate     MA
# 1               3.0      5-6 hours      Unhealthy  B.Com
# 2               3.0      5-6 hours       Moderate  M.Com
# 3               5.0      7-8 hours        Healthy     MD
# 4               3.0      7-8 hours       Moderate     BE
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# 0                                    No                 6                 2
# 1                                   Yes                 0                 4
# 2                                    No                 0                 2
# 3                                   Yes                 1                 2
# 4                                   Yes                 6                 5
#
#   Family History of Mental Illness Depression  Male
# 0                               No         No     0
# 1                              Yes         No     1
# 2                               No         No     0
# 3                              Yes         No     0
# 4                              Yes         No     1

# %%
#Transformando coluna 'Working Professional or Student' em variáveis numéricas

worker_or_student = pd.get_dummies(df['Working Professional or Student'], dtype=int)
df[['Working Professional', 'Student']] = worker_or_student
df.drop(['Working Professional or Student', 'Working Professional'], axis=1, inplace=True)
df.head()
# Out:
#       Name  Age       City         Profession  Academic Pressure  \
# 0    Pooja   37  Ghaziabad            Teacher                NaN
# 1  Reyansh   60     Kalyan  Financial Analyst                NaN
# 2    Manvi   42     Bhopal            Teacher                NaN
# 3     Isha   44      Thane            Teacher                NaN
# 4    Aarav   48     Indore     UX/UI Designer                NaN
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction Sleep Duration  \
# 0            2.0   NaN                 NaN               4.0      7-8 hours
# 1            4.0   NaN                 NaN               3.0      5-6 hours
# 2            2.0   NaN                 NaN               3.0      5-6 hours
# 3            3.0   NaN                 NaN               5.0      7-8 hours
# 4            4.0   NaN                 NaN               3.0      7-8 hours
#
#   Dietary Habits Degree Have you ever had suicidal thoughts ?  \
# 0       Moderate     MA                                    No
# 1      Unhealthy  B.Com                                   Yes
# 2       Moderate  M.Com                                    No
# 3        Healthy     MD                                   Yes
# 4       Moderate     BE                                   Yes
#
#    Work/Study Hours  Financial Stress Family History of Mental Illness  \
# 0                 6                 2                               No
# 1                 0                 4                              Yes
# 2                 0                 2                               No
# 3                 1                 2                              Yes
# 4                 6                 5                              Yes
#
#   Depression  Male  Student
# 0         No     0        1
# 1         No     1        1
# 2         No     0        1
# 3         No     0        1
# 4         No     1        1

# %%
#Transformando coluna 'Depression' em variáveis numéricas

depression = pd.get_dummies(df['Depression'], dtype=int)
df[['No', 'Depression']] = depression
df.drop('No', axis=1, inplace=True)
df.head()
# Out:
#       Name  Age       City         Profession  Academic Pressure  \
# 0    Pooja   37  Ghaziabad            Teacher                NaN
# 1  Reyansh   60     Kalyan  Financial Analyst                NaN
# 2    Manvi   42     Bhopal            Teacher                NaN
# 3     Isha   44      Thane            Teacher                NaN
# 4    Aarav   48     Indore     UX/UI Designer                NaN
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction Sleep Duration  \
# 0            2.0   NaN                 NaN               4.0      7-8 hours
# 1            4.0   NaN                 NaN               3.0      5-6 hours
# 2            2.0   NaN                 NaN               3.0      5-6 hours
# 3            3.0   NaN                 NaN               5.0      7-8 hours
# 4            4.0   NaN                 NaN               3.0      7-8 hours
#
#   Dietary Habits Degree Have you ever had suicidal thoughts ?  \
# 0       Moderate     MA                                    No
# 1      Unhealthy  B.Com                                   Yes
# 2       Moderate  M.Com                                    No
# 3        Healthy     MD                                   Yes
# 4       Moderate     BE                                   Yes
#
#    Work/Study Hours  Financial Stress Family History of Mental Illness  \
# 0                 6                 2                               No
# 1                 0                 4                              Yes
# 2                 0                 2                               No
# 3                 1                 2                              Yes
# 4                 6                 5                              Yes
#
#    Depression  Male  Student
# 0           0     0        1
# 1           0     1        1
# 2           0     0        1
# 3           0     0        1
# 4           0     1        1

# %%
#Transformando coluna 'Depression' em variáveis numéricas

mental_illness_history_in_family = pd.get_dummies(df['Family History of Mental Illness'], dtype=int)
df[['No', 'Family History of Mental Illness']] = mental_illness_history_in_family
df.drop('No', axis=1, inplace=True)
df.head()
# Out:
#       Name  Age       City         Profession  Academic Pressure  \
# 0    Pooja   37  Ghaziabad            Teacher                NaN
# 1  Reyansh   60     Kalyan  Financial Analyst                NaN
# 2    Manvi   42     Bhopal            Teacher                NaN
# 3     Isha   44      Thane            Teacher                NaN
# 4    Aarav   48     Indore     UX/UI Designer                NaN
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction Sleep Duration  \
# 0            2.0   NaN                 NaN               4.0      7-8 hours
# 1            4.0   NaN                 NaN               3.0      5-6 hours
# 2            2.0   NaN                 NaN               3.0      5-6 hours
# 3            3.0   NaN                 NaN               5.0      7-8 hours
# 4            4.0   NaN                 NaN               3.0      7-8 hours
#
#   Dietary Habits Degree Have you ever had suicidal thoughts ?  \
# 0       Moderate     MA                                    No
# 1      Unhealthy  B.Com                                   Yes
# 2       Moderate  M.Com                                    No
# 3        Healthy     MD                                   Yes
# 4       Moderate     BE                                   Yes
#
#    Work/Study Hours  Financial Stress  Family History of Mental Illness  \
# 0                 6                 2                                 0
# 1                 0                 4                                 1
# 2                 0                 2                                 0
# 3                 1                 2                                 1
# 4                 6                 5                                 1
#
#    Depression  Male  Student
# 0           0     0        1
# 1           0     1        1
# 2           0     0        1
# 3           0     0        1
# 4           0     1        1

# %%
#Transformando coluna 'Depression' em variáveis numéricas

suicidal_thoughts = pd.get_dummies(df['Have you ever had suicidal thoughts ?'], dtype=int)
df[['No', 'Have you ever had suicidal thoughts ?']] = suicidal_thoughts
df.drop('No', axis=1, inplace=True)
df.head()
# Out:
#       Name  Age       City         Profession  Academic Pressure  \
# 0    Pooja   37  Ghaziabad            Teacher                NaN
# 1  Reyansh   60     Kalyan  Financial Analyst                NaN
# 2    Manvi   42     Bhopal            Teacher                NaN
# 3     Isha   44      Thane            Teacher                NaN
# 4    Aarav   48     Indore     UX/UI Designer                NaN
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction Sleep Duration  \
# 0            2.0   NaN                 NaN               4.0      7-8 hours
# 1            4.0   NaN                 NaN               3.0      5-6 hours
# 2            2.0   NaN                 NaN               3.0      5-6 hours
# 3            3.0   NaN                 NaN               5.0      7-8 hours
# 4            4.0   NaN                 NaN               3.0      7-8 hours
#
#   Dietary Habits Degree  Have you ever had suicidal thoughts ?  \
# 0       Moderate     MA                                      0
# 1      Unhealthy  B.Com                                      1
# 2       Moderate  M.Com                                      0
# 3        Healthy     MD                                      1
# 4       Moderate     BE                                      1
#
#    Work/Study Hours  Financial Stress  Family History of Mental Illness  \
# 0                 6                 2                                 0
# 1                 0                 4                                 1
# 2                 0                 2                                 0
# 3                 1                 2                                 1
# 4                 6                 5                                 1
#
#    Depression  Male  Student
# 0           0     0        1
# 1           0     1        1
# 2           0     0        1
# 3           0     0        1
# 4           0     1        1

# %%
#Transformando coluna 'Dietary Habits' em variáveis numéricas

df['Dietary Habits'] = pd.Categorical(df['Dietary Habits'], categories=['Unhealthy', 'Moderate', 'Healthy'], ordered=True).codes + 1
df.head()
# Out:
#       Name  Age       City         Profession  Academic Pressure  \
# 0    Pooja   37  Ghaziabad            Teacher                NaN
# 1  Reyansh   60     Kalyan  Financial Analyst                NaN
# 2    Manvi   42     Bhopal            Teacher                NaN
# 3     Isha   44      Thane            Teacher                NaN
# 4    Aarav   48     Indore     UX/UI Designer                NaN
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction Sleep Duration  \
# 0            2.0   NaN                 NaN               4.0      7-8 hours
# 1            4.0   NaN                 NaN               3.0      5-6 hours
# 2            2.0   NaN                 NaN               3.0      5-6 hours
# 3            3.0   NaN                 NaN               5.0      7-8 hours
# 4            4.0   NaN                 NaN               3.0      7-8 hours
#
#    Dietary Habits Degree  Have you ever had suicidal thoughts ?  \
# 0               2     MA                                      0
# 1               1  B.Com                                      1
# 2               2  M.Com                                      0
# 3               3     MD                                      1
# 4               2     BE                                      1
#
#    Work/Study Hours  Financial Stress  Family History of Mental Illness  \
# 0                 6                 2                                 0
# 1                 0                 4                                 1
# 2                 0                 2                                 0
# 3                 1                 2                                 1
# 4                 6                 5                                 1
#
#    Depression  Male  Student
# 0           0     0        1
# 1           0     1        1
# 2           0     0        1
# 3           0     0        1
# 4           0     1        1

# %%
plt.figure(figsize=(8, 6))  
sns.heatmap(df.isnull(), cmap='viridis', cbar=False)  
plt.title('Mapa de Calor de Dados Nulos')  
plt.show()

# %%
px.box(df, x="Gender", y="Age", color="Depression", title="Relação entre gênero e idade com depressão")

# %%
px.histogram(df, x="Age", y="Job Satisfaction", color="Depression", barmode="overlay",
             title="Relação e distribuição entre insatisfação no trabalho, idade e depressão")

# %%
px.box(df, x="Depression", y="Job Satisfaction", color="Depression", title="Satisfação de trabalho e sua relação com a depressão")

# %%
px.histogram(df, x="Age", y="Work Pressure", color="Depression", barmode="overlay",
            title="Relação e distribuição entre pressão de trabalho, idade e depressão")

# %%
px.scatter(df, x="Age", y="Depression", title="Distribuição das idades das pessoas com e sem depressão")

# %%
px.scatter(df, x="Profession", y="Age", color="Depression", title="Presença de depressão nas profissões")

# %%
px.box(df, x="Depression", y="Work/Study Hours", color="Depression", title="Quantidade de horas trabalhadas e sua relação com a depressão")

# %%
px.box(df, x="Depression", y="Dietary Habits", color="Depression", title="Hábitos alimentares relacionados com a depressão")

# %%
px.box(df, x="Depression", y="Sleep Duration", color="Depression", title="Duração do sono relacionada com a depressão")

# %%
px.histogram(df, x="Age", y="Depression", title="Presença de depressão nas idades")
